# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import random

# %%
x=[random.randint(0,1000) for i in range(1000)]
y=[random.randint(0,1000) for i in range(1000)]

x=np.asanyarray(x)
y=np.asanyarray(y)

# %%
df=pd.DataFrame({'x1':x,'x2':y,'y':x+y})
df
# Out:
#       x1   x2     y
# 0    787  440  1227
# 1    786  515  1301
# 2    276  676   952
# 3    664  255   919
# 4    214  995  1209
# ..   ...  ...   ...
# 995  305  692   997
# 996  123  782   905
# 997  532  955  1487
# 998  299   77   376
# 999  257  128   385
#
# [1000 rows x 3 columns]

# %%
xtr,xte,ytr,yte=train_test_split(df[['x1','x2']],df['y'],test_size=0.2)

# %%
xtr.shape
# Out:
# (800, 2)

# %%
ytr.shape
# Out:
# (800,)

# %%
model =keras.Sequential()
model.add(keras.layers.Dense(6,activation='relu',input_shape=(2,)))
model.add(keras.layers.Dense(6,activation='relu'))

model.add(keras.layers.Dense(1,activation='relu'))

model.compile(optimizer='adam',loss='mse',metrics=['mae'])
model.fit(xtr,ytr,epochs=350)
# Out:
# Epoch 1/350
#  9/25 [=========>....................] - ETA: 0s - loss: 383762.8438 - mae: 571.4369
# 2023-05-04 16:04:10.789914: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - 0s 7ms/step - loss: 332456.7188 - mae: 531.3718
# Epoch 2/350
# 25/25 [==============================] - 0s 6ms/step - loss: 210576.3281 - mae: 421.2453
# Epoch 3/350
# 25/25 [==============================] - 0s 6ms/step - loss: 123667.8281 - mae: 320.2380
# Epoch 4/350
# 25/25 [==============================] - 0s 7ms/step - loss: 70608.6250 - mae: 237.3339
# Epoch 5/350
# 25/25 [==============================] - 0s 7ms/step - loss: 36208.7617 - mae: 164.6008
# Epoch 6/350
# 25/25 [==============================] - 0s 7ms/step - loss: 17413.8770 - mae: 110.3044
# Epoch 7/350
# 25/25 [==============================] - 0s 7ms/step - loss: 8562.1094 - mae: 77.8839
# Epoch 8/350
# ...

# %%
ypred=model.predict(xte)
# Out:
# 7/7 [==============================] - 0s 5ms/step

# %%
ypred.round()
# Out:
# array([[ 919.],
#        [1664.],
#        [ 606.],
#        [ 910.],
#        [1306.],
#        [1239.],
#        [1022.],
#        [ 762.],
#        [ 786.],
#        [1181.],
#        [ 764.],
#        [1241.],
#        [1671.],
#        [1165.],
#        [ 936.],
#        [ 826.],
#        [1069.],
#        [1206.],
#        [1121.],
#        [1041.],
#        [ 596.],
#        [ 683.],
#        [ 862.],
#        [ 938.],
#        [ 852.],
#        [ 886.],
#        [ 943.],
#        [ 821.],
#        [1008.],
#        [ 903.],
#        [1308.],
#        [ 457.],
#        [ 945.],
#        [ 811.],
#        [1309.],
#        [1281.],
#        [1403.],
#        [ 479.],
#        [ 438.],
#        [1322.],
#        [1176.],
#        [1696.],
#        [ 531.],
#        [1187.],
#        [ 476.],
#        [1423.],
#        [1230.],
#        [1249.],
#        [1058.],
#        [ 327.],
#        [ 181.],
#        [ 785.],
#        [ 279.],
#        [1223.],
#        [ 533.],
# ...

# %%
from sklearn.metrics import mean_squared_error
1-mean_squared_error(yte,ypred)
# Out:
# 0.9962574248819146
